# %%
import pandas as pd

# %%
northwind_order_details = pd.read_csv(r'C:\Users\mende\OneDrive - Benemérita Universidad Autónoma de Puebla\Análisis de datos\Projects\impacto-campanas\impacto-campa-as\datasets\northwind_order_details.csv')

# %%
northwind_orders = pd.read_csv(r'C:\Users\mende\OneDrive - Benemérita Universidad Autónoma de Puebla\Análisis de datos\Projects\impacto-campanas\impacto-campa-as\datasets\northwind_orders.csv')

# %%
northwind_order_details.merge(northwind_orders, on = 'order_id', how = 'outer')
# Out:
#       order_id  product_id  unit_price  quantity  discount customer_id  \
# 0        10248          11       14.00        12      0.00       VINET
# 1        10248          42        9.80        10      0.00       VINET
# 2        10248          72       34.80         5      0.00       VINET
# 3        10249          14       18.60         9      0.00       TOMSP
# 4        10249          51       42.40        40      0.00       TOMSP
# ...        ...         ...         ...       ...       ...         ...
# 2150     11077          64       33.25         2      0.03       RATTC
# 2151     11077          66       17.00         1      0.00       RATTC
# 2152     11077          73       15.00         2      0.01       RATTC
# 2153     11077          75        7.75         4      0.00       RATTC
# 2154     11077          77       13.00         2      0.00       RATTC
#
#       employee_id  order_date required_date shipped_date  ship_via  freight  \
# ...

# %%
northwind_order_details.describe()
# Out:
#            order_id   product_id   unit_price     quantity     discount
# count   2155.000000  2155.000000  2155.000000  2155.000000  2155.000000
# mean   10659.375870    40.793039    26.218520    23.812993     0.056167
# std      241.378032    22.159019    29.827418    19.022047     0.083450
# min    10248.000000     1.000000     2.000000     1.000000     0.000000
# 25%    10451.000000    22.000000    12.000000    10.000000     0.000000
# 50%    10657.000000    41.000000    18.400000    20.000000     0.000000
# 75%    10862.500000    60.000000    32.000000    30.000000     0.100000
# max    11077.000000    77.000000   263.500000   130.000000     0.250000
